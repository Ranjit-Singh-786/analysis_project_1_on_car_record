# %% [markdown]
# >> # EXPLORATORY DATA ANALYSIS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df=pd.read_csv('cars.csv',delimiter=';')
df.head()
# Out:
#                          Car     MPG Cylinders Displacement Horsepower  \
# 0                     STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1  Chevrolet Chevelle Malibu    18.0         8        307.0      130.0
# 2          Buick Skylark 320    15.0         8        350.0      165.0
# 3         Plymouth Satellite    18.0         8        318.0      150.0
# 4              AMC Rebel SST    16.0         8        304.0      150.0
#
#    Weight Acceleration Model Origin
# 0  DOUBLE       DOUBLE   INT    CAT
# 1   3504.         12.0    70     US
# 2   3693.         11.5    70     US
# 3   3436.         11.0    70     US
# 4   3433.         12.0    70     US

# %%
df.shape
# Out:
# (407, 9)

# %%
df['Car'].value_counts()
# Out:
# Toyota Corolla         9
# Ford Pinto             6
# Ford Maverick          5
# Volkswagen Rabbit      5
# AMC Matador            5
#                       ..
# Chevrolet Vega (sw)    1
# Renault 12 (sw)        1
# Volkswagen Type 3      1
# Ford Thunderbird       1
# AMC Rebel SST (sw)     1
# Name: Car, Length: 309, dtype: int64

# %%
df=df.iloc[1:]

# %%
df.isnull().sum()
# Out:
# Car             0
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      0
# Weight          0
# Acceleration    0
# Model           0
# Origin          0
# dtype: int64

# %%
df['Origin'].value_counts()
# Out:
# US        254
# Japan      79
# Europe     73
# Name: Origin, dtype: int64

# %%
df['Displacement'].value_counts()
# Out:
# 97.00    22
# 350.0    19
# 98.00    18
# 250.0    17
# 318.0    17
#          ..
# 390.0     1
# 76.00     1
# 454.0     1
# 115.0     1
# 83.00     1
# Name: Displacement, Length: 83, dtype: int64

# %%
df['Horsepower'].value_counts()
# Out:
# 150.0    22
# 90.00    20
# 110.0    19
# 88.00    19
# 100.0    17
#          ..
# 107.0     1
# 142.0     1
# 220.0     1
# 91.00     1
# 116.0     1
# Name: Horsepower, Length: 94, dtype: int64

# %%
df['MPG'].value_counts()
# Out:
# 13.0    20
# 14.0    19
# 18.0    17
# 15.0    16
# 26.0    14
#         ..
# 31.9     1
# 31.3     1
# 28.4     1
# 41.5     1
# 39.0     1
# Name: MPG, Length: 130, dtype: int64

# %%
df['Cylinders'].value_counts()
# Out:
# 4    207
# 8    108
# 6     84
# 3      4
# 5      3
# Name: Cylinders, dtype: int64

# %%
sns.relplot(x='Displacement' ,y='Weight',data=df.query("Origin=='US'"),kind='line')

# %%
df.dtypes
# Out:
# Car             object
# MPG             object
# Cylinders       object
# Displacement    object
# Horsepower      object
# Weight          object
# Acceleration    object
# Model           object
# Origin          object
# dtype: object

# %%
df['Model']=df['Model'].astype('int32')

# %%
df.dtypes
# Out:
# Car              object
# MPG             float32
# Cylinders         int32
# Displacement    float32
# Horsepower      float32
# Weight          float64
# Acceleration    float32
# Model             int32
# Origin           object
# dtype: object

# %%
sns.catplot(x='Origin',y='Weight',data=df,kind='bar')
plt.grid(axis='y',color='k')

# %%
df[df['Origin']=='Japan']['Weight'].describe()
# Out:
# count      79.000000
# mean     2221.227848
# std       320.497248
# min      1613.000000
# 25%      1985.000000
# 50%      2155.000000
# 75%      2412.500000
# max      2930.000000
# Name: Weight, dtype: float64

# %%
sns.catplot(x='Cylinders',y='Displacement',data=df,kind='boxen')
plt.title('cylinder with Displacement',fontsize=20,color='k')
# Out:
# Text(0.5, 1.0, 'cylinder with Displacement')

# %%
sns.catplot(x='Cylinders',y='Horsepower',data=df,kind='boxen')
plt.title('cylinder with horespower',fontsize=20,color='k')
# Out:
# Text(0.5, 1.0, 'cylinder with horespower')

# %%
sns.catplot(x='Cylinders',y='Weight',data=df,kind='box')
plt.title('cylinder with Weight',fontsize=20,color='k')
# Out:
# Text(0.5, 1.0, 'cylinder with Weight')

# %%
sns.relplot(x='Displacement',y='Weight',data=df,hue='Origin')
plt.title('Displacement with Weight linear relationship',fontsize=20,color='k')

# %%
sns.relplot(x='Displacement',y='Weight',data=df,hue='Origin',col='Origin')
plt.title('Displacement with Weight linear relationship',fontsize=20,color='k')
# Out:
# Text(0.5, 1.0, 'Displacement with Weight linear relationship')

# %%
sns.relplot(x='Displacement',y='Weight',data=df,hue='Origin',col='Origin',row='Cylinders')
plt.title('Displacement with Weight linear relationship',fontsize=20,color='k')
# Out:
# Text(0.5, 1.0, 'Displacement with Weight linear relationship')

# %%
df.head()
# Out:
#                          Car   MPG Cylinders Displacement Horsepower Weight  \
# 1  Chevrolet Chevelle Malibu  18.0         8        307.0      130.0  3504.
# 2          Buick Skylark 320  15.0         8        350.0      165.0  3693.
# 3         Plymouth Satellite  18.0         8        318.0      150.0  3436.
# 4              AMC Rebel SST  16.0         8        304.0      150.0  3433.
# 5                Ford Torino  17.0         8        302.0      140.0  3449.
#
#   Acceleration Model Origin
# 1         12.0    70     US
# 2         11.5    70     US
# 3         11.0    70     US
# 4         12.0    70     US
# 5         10.5    70     US

# %%
df.dtypes
# Out:
# Car              object
# MPG             float32
# Cylinders         int32
# Displacement    float32
# Horsepower      float32
# Weight          float32
# Acceleration    float64
# Model             int32
# Origin           object
# dtype: object

# %%
df['Model']=df['Model'].astype('int')

# %%
df['Car'].value_counts()
# Out:
# Toyota Corolla                          9
# Ford Pinto                              6
# Volkswagen Rabbit                       5
# AMC Matador                             5
# Ford Maverick                           5
# AMC Gremlin                             4
# Chevrolet Impala                        4
# Peugeot 504                             4
# AMC Hornet                              4
# Chevrolet Chevette                      4
# Ford Gran Torino                        3
# Volkswagen Dasher                       3
# Plymouth Duster                         3
# Chevrolet Caprice Classic               3
# Chevrolet Citation                      3
# Ford Galaxie 500                        3
# Chevrolet Vega                          3
# Dodge Colt                              3
# Chevrolet Nova                          3
# Honda Civic                             3
# Pontiac Catalina                        3
# AMC Matador (sw)                        2
# ...

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
df=pd.read_csv('set.csv')
df.head()
# Out:
#    Unnamed: 0                        Car   MPG  Cylinders  Displacement  \
# 0           1  Chevrolet Chevelle Malibu  18.0          8         307.0
# 1           2          Buick Skylark 320  15.0          8         350.0
# 2           3         Plymouth Satellite  18.0          8         318.0
# 3           4              AMC Rebel SST  16.0          8         304.0
# 4           5                Ford Torino  17.0          8         302.0
#
#    Horsepower  Weight  Acceleration  Model Origin
# 0       130.0  3504.0          12.0     70     US
# 1       165.0  3693.0          11.5     70     US
# 2       150.0  3436.0          11.0     70     US
# 3       150.0  3433.0          12.0     70     US
# 4       140.0  3449.0          10.5     70     US

# %%
grouped=df.groupby(by='Origin')

# %%
grouped['Cylinders'].max()
# Out:
# Origin
# Europe    6
# Japan     6
# US        8
# Name: Cylinders, dtype: int64

# %%
grouped['Cylinders'].min()
# Out:
# Origin
# Europe    4
# Japan     3
# US        4
# Name: Cylinders, dtype: int64

# %%
grouped['Model'].max()
# Out:
# Origin
# Europe    82
# Japan     82
# US        82
# Name: Model, dtype: int64

# %%
grouped['Model'].value_counts()
# Out:
# Origin  Model
# Europe  80        9
#         76        8
#         73        7
#         70        6
#         74        6
#         75        6
#         78        6
#         71        5
#         72        5
#         81        5
#         77        4
#         79        4
#         82        2
# Japan   80       13
#         81       12
#         82        9
#         78        8
#         74        6
#         77        6
#         72        5
#         71        4
#         73        4
#         75        4
#         76        4
#         70        2
#         79        2
# US      73       29
#         70       27
#         79       23
#         76       22
#         78       22
#         71       20
#         75       20
#         82       20
#         72       18
#         77       18
#         74       15
#         81       13
#         80        7
# Name: Model, dtype: int64

# %%
grouped['Model'].value_counts()['US']
# Out:
# Model
# 73    29
# 70    27
# 79    23
# 76    22
# 78    22
# 71    20
# 75    20
# 82    20
# 72    18
# 77    18
# 74    15
# 81    13
# 80     7
# Name: Model, dtype: int64

# %%
grouped['Model'].value_counts()[['Japan']]
# Out:
# Origin  Model
# Japan   80       13
#         81       12
#         82        9
#         78        8
#         74        6
#         77        6
#         72        5
#         71        4
#         73        4
#         75        4
#         76        4
#         70        2
#         79        2
# Name: Model, dtype: int64

# %%
grouped['Model'].value_counts()['Europe']
# Out:
# Model
# 80    9
# 76    8
# 73    7
# 70    6
# 74    6
# 75    6
# 78    6
# 71    5
# 72    5
# 81    5
# 77    4
# 79    4
# 82    2
# Name: Model, dtype: int64

# %%
grouped['Model'].value_counts()['Europe'].sum()
# Out:
# 73

# %%
grouped['Model'].value_counts()['US'].sum()          # us maximum model containing
# Out:
# 254

# %%
grouped['Model'].value_counts()['Japan'].sum()
# Out:
# 79

# %%
grouped['Model','MPG'].mean()
# Out:
# <ipython-input-23-8c838e1be86d>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped['Model','MPG'].mean()
#             Model        MPG
# Origin
# Europe  75.739726  26.745205
# Japan   77.443038  30.450633
# US      75.500000  19.688189

# %%
grouped['Model','MPG','Cylinders'].max()
# Out:
# <ipython-input-32-1b0dbf9646a9>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped['Model','MPG','Cylinders'].max()
#         Model   MPG  Cylinders
# Origin
# Europe     82  44.3          6
# Japan      82  46.6          6
# US         82  39.0          8

# %%
grouped['Model','MPG','Cylinders'].max().loc[['US']]
# Out:
# <ipython-input-37-82d44017ae7f>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped['Model','MPG','Cylinders'].max().loc[['US']]
#         Model   MPG  Cylinders
# Origin
# US         82  39.0          8

# %%
grouped.get_group('US').head(2)
# Out:
#    Unnamed: 0                        Car   MPG  Cylinders  Displacement  \
# 0           1  Chevrolet Chevelle Malibu  18.0          8         307.0
# 1           2          Buick Skylark 320  15.0          8         350.0
#
#    Horsepower  Weight  Acceleration  Model Origin
# 0       130.0  3504.0          12.0     70     US
# 1       165.0  3693.0          11.5     70     US

# %%
grouped.get_group('US').shape
# Out:
# (254, 10)

# %%
grouped.get_group('Japan').head()
# Out:
#     Unnamed: 0                     Car   MPG  Cylinders  Displacement  \
# 20          21  Toyota Corolla Mark ii  24.0          4         113.0
# 24          25            Datsun PL510  27.0          4          97.0
# 35          36            Datsun PL510  27.0          4          97.0
# 37          38          Toyota Corolla  25.0          4         113.0
# 60          61     Toyota Corolla 1200  31.0          4          71.0
#
#     Horsepower  Weight  Acceleration  Model Origin
# 20        95.0  2372.0          15.0     70  Japan
# 24        88.0  2130.0          14.5     70  Japan
# 35        88.0  2130.0          14.5     71  Japan
# 37        95.0  2228.0          14.0     71  Japan
# 60        65.0  1773.0          19.0     71  Japan

# %%
grouped.get_group('Japan').shape
# Out:
# (79, 10)

# %%
grouped.get_group('Europe').head()
# Out:
#     Unnamed: 0                           Car   MPG  Cylinders  Displacement  \
# 10          11          Citroen DS-21 Pallas   0.0          4         133.0
# 25          26  Volkswagen 1131 Deluxe Sedan  26.0          4          97.0
# 26          27                   Peugeot 504  25.0          4         110.0
# 27          28                   Audi 100 LS  24.0          4         107.0
# 28          29                      Saab 99e  25.0          4         104.0
#
#     Horsepower  Weight  Acceleration  Model  Origin
# 10       115.0  3090.0          17.5     70  Europe
# 25        46.0  1835.0          20.5     70  Europe
# 26        87.0  2672.0          17.5     70  Europe
# 27        90.0  2430.0          14.5     70  Europe
# 28        95.0  2375.0          17.5     70  Europe

# %%
grouped.get_group('Europe').shape
# Out:
# (73, 10)

# %%
grouped.get_group('US').sum(axis=1)          # it is done by rows oposite axis here
# Out:
# 0      4050.0
# 1      4314.5
# 2      4014.0
# 3      3997.0
# 4      4001.5
#         ...
# 400    3722.3
# 401    3546.6
# 403    3047.6
# 404    3361.6
# 405    3463.4
# Length: 254, dtype: float64

# %%
grouped.get_group('US').sum(axis=1).shape
# Out:
# (254,)

# %%
1+18+8+307+130+3504+12+70
# Out:
# 4050

# %%
grouped.get_group('US').sum(axis='rows')     # oposite addition here row columns and column row
# Out:
# Unnamed: 0                                                  47779
# Car             Chevrolet Chevelle MalibuBuick Skylark 320Plym...
# MPG                                                        5000.8
# Cylinders                                                    1596
# Displacement                                              62975.5
# Horsepower                                                29975.0
# Weight                                                   856666.0
# Acceleration                                               3795.4
# Model                                                       19177
# Origin          USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# dtype: object

# %%
# i am prooving this addition only Cylinder column
grouped.get_group('US').sum()['Cylinders']
# Out:
# 1596

# %%
grouped.get_group('US')['Car'].unique().shape
# maximum cars contains the us
# Out:
# (192,)

# %%
grouped.get_group('Japan')['Car'].unique().shape
# Out:
# (57,)

# %%
grouped.get_group('Europe')['Car'].unique().shape
# Out:
# (59,)

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(grouped.get_group('US')['Displacement'],y=grouped.get_group('US')['Weight'],hue=grouped.get_group('US')['Cylinders'],palette=['r','y','c'])
plt.title('weight vs displacement in us',fontsize=20)
# Out:
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'weight vs displacement in us')

# %%
plt.figure(figsize=(10,12))
sns.relplot(grouped.get_group('US')['Displacement'],y=grouped.get_group('US')['Weight'],hue=grouped.get_group('US')['Cylinders'],kind='line',palette=['r','y','c'])
plt.title('weight vs displacement in us',fontsize=20)
# Out:
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'weight vs displacement in us')

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(grouped.get_group('Japan')['Displacement'],y=grouped.get_group('Japan')['Weight'],hue=grouped.get_group('Japan')['Cylinders'])
plt.title('weight vs displacement in Japan',fontsize=20)
# japan has no Cylinder
# Out:
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'weight vs displacement in Japan')

# %%
plt.figure(figsize=(10,8))
sns.relplot(grouped.get_group('Japan')['Displacement'],y=grouped.get_group('Japan')['Weight'],kind='line',hue=grouped.get_group('Japan')['Cylinders'])
plt.title('weight vs displacement in Japan',fontsize=20)
# Out:
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'weight vs displacement in Japan')

# %%
plt.figure(figsize=(10,8))
sns.relplot(grouped.get_group('Japan')['Displacement'],y=grouped.get_group('Japan')['Weight'],kind='line',color='c')
plt.title('weight vs displacement in Japan',fontsize=20)
# Out:
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'weight vs displacement in Japan')

# %%
df[df['Origin']=='Japan']['Cylinders'].value_counts()
# Out:
# 4    69
# 6     6
# 3     4
# Name: Cylinders, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(grouped.get_group('Europe')['Displacement'],y=grouped.get_group('Europe')['Weight'],hue=grouped.get_group('Europe')['Cylinders'],palette=['r','g','b'],sizes=(200,400))
plt.title('weight vs displacement in Europe',fontsize=20)
# Out:
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'weight vs displacement in Europe')

# %%
plt.figure(figsize=(10,8))
sns.relplot(grouped.get_group('Europe')['Displacement'],y=grouped.get_group('Europe')['Weight'],kind='line',hue=grouped.get_group('Europe')['Cylinders'],palette=['r','g','b'],sizes=(200,400))
plt.title('weight vs displacement in Europe',fontsize=20)
# Out:
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'weight vs displacement in Europe')

# %%
plt.figure(figsize=(10,8))
sns.relplot(grouped.get_group('Europe')['Displacement'],y=grouped.get_group('Europe')['Weight'],kind='line',color='g',sizes=(200,400))
plt.title('weight vs displacement in Europe',fontsize=20)
# Out:
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'weight vs displacement in Europe')

# %%
plt.figure(figsize=(10,8))
sns.distplot(df['Cylinders'])
plt.title('distribution of cylinders',fontsize=20,color='r')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.countplot(df['Cylinders'])
# Out:
# <AxesSubplot:xlabel='Cylinders', ylabel='count'>

# %%
plt.figure(figsize=(10,8))
sns.countplot(df['Cylinders'])
# maximum 4 cylinderes availabel
# Out:
# <AxesSubplot:xlabel='Cylinders', ylabel='count'>

# %%
plt.figure(figsize=(10,8))
sns.countplot(grouped.get_group('US')['Cylinders'])
plt.title('cylinderes in us',fontsize=20)
# Out:
# Text(0.5, 1.0, 'cylinderes in us')

# %%
plt.figure(figsize=(10,8))
sns.countplot(grouped.get_group('Japan')['Cylinders'])
plt.title('cylinderes in japan',fontsize=20)
# Out:
# Text(0.5, 1.0, 'cylinderes in japan')

# %%
plt.figure(figsize=(10,8))
sns.countplot(grouped.get_group('Europe')['Cylinders'])
plt.title('cylinderes in europe',fontsize=20)
# Out:
# Text(0.5, 1.0, 'cylinderes in europe')

# %%
df
# Out:
#      Unnamed: 0                        Car   MPG  Cylinders  Displacement  \
# 0             1  Chevrolet Chevelle Malibu  18.0          8         307.0
# 1             2          Buick Skylark 320  15.0          8         350.0
# 2             3         Plymouth Satellite  18.0          8         318.0
# 3             4              AMC Rebel SST  16.0          8         304.0
# 4             5                Ford Torino  17.0          8         302.0
# ..          ...                        ...   ...        ...           ...
# 401         402            Ford Mustang GL  27.0          4         140.0
# 402         403          Volkswagen Pickup  44.0          4          97.0
# 403         404              Dodge Rampage  32.0          4         135.0
# 404         405                Ford Ranger  28.0          4         120.0
# 405         406                 Chevy S-10  31.0          4         119.0
#
#      Horsepower  Weight  Acceleration  Model  Origin
# ...

# %%
sns.catplot(x='Origin',y='Weight',data=df.query("Cylinders==4"),kind='bar')

# %%
sns.catplot(x='Origin',y='Weight',data=df.query("Cylinders==5"),kind='bar')

# %%
sns.catplot(x='Origin',y='Weight',data=df.query("Cylinders==3"),kind='bar')

# %%
plt.figure(figsize=(10,8))
sns.countplot(df['Model'])
plt.title('all models in my dataframe')
# Out:
# Text(0.5, 1.0, 'all models in my dataframe')

# %%
plt.figure(figsize=(10,8))
sns.countplot(grouped.get_group('US')['Model'])
plt.title('models in us',fontsize=20)
# Out:
# Text(0.5, 1.0, 'models in us')

# %%
plt.figure(figsize=(10,8))
sns.countplot(grouped.get_group('Japan')['Model'])
plt.title('models in japan ',fontsize=20)
# Out:
# Text(0.5, 1.0, 'models in japan ')

# %%
plt.figure(figsize=(10,8))
sns.countplot(grouped.get_group('Europe')['Model'])
plt.title('models in Europe ',fontsize=20)
# Out:
# Text(0.5, 1.0, 'models in Europe ')

# %%
df=df.drop('Car',axis=1)

# %%
df.head(2)
# Out:
#    Unnamed: 0   MPG  Cylinders  Displacement  Horsepower  Weight  \
# 0           1  18.0          8         307.0       130.0  3504.0
# 1           2  15.0          8         350.0       165.0  3693.0
#
#    Acceleration  Model Origin
# 0          12.0     70     US
# 1          11.5     70     US

# %%
df=pd.get_dummies(df,columns=['Origin'])

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
df.head(2)
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  Model  \
# 0  18.0          8         307.0       130.0  3504.0          12.0     70
# 1  15.0          8         350.0       165.0  3693.0          11.5     70
#
#    Origin_Europe  Origin_Japan  Origin_US
# 0              0             0          1
# 1              0             0          1

# %%
df.corr()
# Out:
#                     MPG  Cylinders  Displacement  Horsepower    Weight  \
# MPG            1.000000  -0.735563     -0.764277   -0.726670 -0.787510
# Cylinders     -0.735563   1.000000      0.951787    0.823467  0.895220
# Displacement  -0.764277   0.951787      1.000000    0.873758  0.932475
# Horsepower    -0.726670   0.823467      0.873758    1.000000  0.840811
# Weight        -0.787510   0.895220      0.932475    0.840811  1.000000
# Acceleration   0.424490  -0.522452     -0.557984   -0.682047 -0.430086
# Model          0.586234  -0.360762     -0.381714   -0.419929 -0.315389
# Origin_Europe  0.206109  -0.362696     -0.381176   -0.286320 -0.303254
# Origin_Japan   0.433412  -0.394958     -0.431845   -0.287766 -0.440520
# Origin_US     -0.518074   0.610870      0.655708    0.462584  0.600972
#
#                Acceleration     Model  Origin_Europe  Origin_Japan  Origin_US
# MPG                0.424490  0.586234       0.206109      0.433412  -0.518074
# ...

# %%
plt.figure(figsize=(10,9))
sns.heatmap(df.corr(method='kendall'),annot=True,cmap=plt.cm.bone)
plt.title('co-relation on full dataframe',fontsize=20,color='k')
plt.show()

# %%
pd.pivot_table(columns=['Cylinders'],index='Origin',values='Weight',aggfunc=sum,data=df2)
# Out:
# Cylinders       3         4       5         6         8
# Origin
# Europe        NaN  154659.0  9310.0   13530.0       NaN
# Japan      9594.0  148591.0     NaN   17292.0       NaN
# US            NaN  175476.0     NaN  237829.0  443361.0

# %%
pd.pivot_table(columns=['Cylinders'],index='Origin',values='Weight',aggfunc=min,data=df2)
# Out:
# Cylinders       3       4       5       6       8
# Origin
# Europe        NaN  1825.0  2830.0  3140.0     NaN
# Japan      2124.0  1613.0     NaN  2807.0     NaN
# US            NaN  1800.0     NaN  2472.0  3086.0

# %%
type(pd.pivot_table(columns=['Cylinders'],index='Origin',values='Weight',aggfunc=min,data=df2).unstack())
# Out:
# pandas.core.series.Series

# %%
pd.pivot_table(columns=['Cylinders'],index='Origin',values='Weight',aggfunc=min,data=df2).unstack()
# Out:
# Cylinders  Origin
# 3          Europe       NaN
#            Japan     2124.0
#            US           NaN
# 4          Europe    1825.0
#            Japan     1613.0
#            US        1800.0
# 5          Europe    2830.0
#            Japan        NaN
#            US           NaN
# 6          Europe    3140.0
#            Japan     2807.0
#            US        2472.0
# 8          Europe       NaN
#            Japan        NaN
#            US        3086.0
# dtype: float64

# %%
pd.pivot_table(columns=['Cylinders'],index='Origin',values='Weight',aggfunc=min,data=df2).unstack().index
# this is multiindex
# Out:
# MultiIndex([(3, 'Europe'),
#             (3,  'Japan'),
#             (3,     'US'),
#             (4, 'Europe'),
#             (4,  'Japan'),
#             (4,     'US'),
#             (5, 'Europe'),
#             (5,  'Japan'),
#             (5,     'US'),
#             (6, 'Europe'),
#             (6,  'Japan'),
#             (6,     'US'),
#             (8, 'Europe'),
#             (8,  'Japan'),
#             (8,     'US')],
#            names=['Cylinders', 'Origin'])

# %%
pd.pivot_table(columns=['Cylinders'],index='Origin',values='Weight',aggfunc=min,data=df2).unstack()
# Out:
# Cylinders  Origin
# 3          Europe       NaN
#            Japan     2124.0
#            US           NaN
# 4          Europe    1825.0
#            Japan     1613.0
#            US        1800.0
# 5          Europe    2830.0
#            Japan        NaN
#            US           NaN
# 6          Europe    3140.0
#            Japan     2807.0
#            US        2472.0
# 8          Europe       NaN
#            Japan        NaN
#            US        3086.0
# dtype: float64

# %% [markdown]
# ## fetch the value in multiindex sereis

# %%
pd.pivot_table(columns=['Cylinders'],index='Origin',values='Weight',aggfunc=min,data=df2).unstack()[(3,'Japan')]
# fetch the value in multinindex series
# Out:
# 2124.0

# %%
pd.pivot_table(columns=['Cylinders'],index='Origin',values='Weight',aggfunc=min,data=df2).unstack()[(3)]
# fetch the value in multinindex series
# Out:
# Origin
# Europe       NaN
# Japan     2124.0
# US           NaN
# dtype: float64

# %%
pd.pivot_table(columns=['Cylinders'],index='Origin',values='Weight',aggfunc=min,data=df2).unstack()[(8,'US')]
# fetch the value in multinindex series
# Out:
# 3086.0

# %% [markdown]
# # exploratory data analysis project finished
